# %% [markdown]
# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.linear_model import LinearRegression
# #Dummy data
# x = np.array([500, 1000, 1500, 2000, 2500]).reshape(-1, 1)
# y = np.array([150000, 200000, 250000, 280000, 350000])
# #Fit MODEL
# model = Linearegression()
# model.fit(X, Y)
# y_pred = model.predict(X)
# print(y_pred)
# #Visualization
# plt.scatter(X, y, color="blue")
# plt.plot(X, y_pred, color="red")
# plt.xlabel("House Size (sq ft)")
#
# plt.ylabel("Price ($)")
# plt.title("Simple linear Regression")
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
#Dummy data
x = np.array([500, 1000, 1500, 2000, 2500]).reshape(-1, 1)
y = np.array([150000, 200000, 250000, 280000, 350000])
#Fit MODEL
model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)
print(y_pred)
#Visualization
plt.scatter(x, y, color="blue")
plt.plot(x, y_pred, color="red")
plt.xlabel("House Size (sq ft)")

plt.ylabel("Price ($)")
plt.title("Simple linear Regression")
plt.show()
# Out:
# [150000. 198000. 246000. 294000. 342000.]

# %%
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

#load  datasets
diabetes = load_diabetes(as_frame=True)
x = diabetes.data
y = diabetes.target

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

model = LinearRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

print(f"MSE: {mean_squared_error(y_test, y_pred)}")
print(f"R2: {r2_score(y_test, y_pred)}")
# Out:
# MSE: 2900.1936284934814
# R2: 0.4526027629719195

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt

# Generate sample data
x = np.linspace(0, 10, 20).reshape(-1,1)
y = 3 * x**2 + np.random.randn(20).reshape(-1,1) * 5 #noisy quadratic data

#linear model (underfit)
model_lin = LinearRegression()
model_lin.fit(x, y)

#polynomial model (overfit)
poly_model = make_pipeline(PolynomialFeatures(3), LinearRegression())
poly_model.fit(x, y)

#Predictions
x_test = np.linspace(0, 10, 100).reshape(-1, 1)
y_lin_pred = model_lin.predict(x_test)
y_poly_pred = poly_model.predict(x_test)

plt.scatter(x, y, color="blue")
plt.plot(x_test, y_lin_pred, color="green", label="Linear (underfit)")
plt.plot(x_test, y_poly_pred, color="red", label="Polynomial (overfit)")
plt.legend()
plt.show()

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.matrix import accuracy_score,
form sklearn.metrics import confusion_matrix, classification_report
#load data (only 2 classes for binary case)
iris = load_iris()
x = iris.data[iris.target !=2] # keep only class 0 and 1
y = iris.target[iris.target != 2]
#Train-test split
x_train, x_test, y_train, y_test = train_test_split(x, y, test size=0.2,random_state=42)
#Logistic Regression
clf = LogisticRegression()
clf.fit(x_train, y_train)
y_pred = clf.predict(x_test)
print(f"Accuracy:, accuracy_score(y_test, y_pred)")
print("Confusion Matrix:"),confusion_matrix(y_test, y_pred)
print("Classification Report:"),classification_report(y_test, y_pred)

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as npY
y_true = np.array([3, -0.5, 2, 7])
y_pred = np.array([2.5, 0.0, 2, 8])
mse = mean_squared_error(y_true, y_pred)
#rmse = mean_squared
R2 = r2_score(y_true, y_pred)
print(f"MSE: {mse}, R2: {R2}")
# Out:
# MSE: 0.375, R2: 0.9486081370449679

# %%
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
import numpy as np
y_true  = [0,0,1,1,1,0,1,0,1,0]
y_pred = [ 0,0,1,0,1,0,1,1,1,0]
y_prob = [0.1,0.4,0.9,0.3,0.8,0.2,0.9,0.7,0.85,0.05] # Corrected length to match y_true
print(f"Confusion Matrix:\n{confusion_matrix(y_true, y_pred)}") # Fixed print syntax
print(f"Report:\n{classification_report(y_true, y_pred)}") # Fixed print syntax
print(f"ROC-AUC: {roc_auc_score(y_true, y_prob)}") # Fixed print syntax
# Out:
# Confusion Matrix:
# [[4 1]
#  [1 4]]
# Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.80      0.80         5
#            1       0.80      0.80      0.80         5
#
#     accuracy                           0.80        10
#    macro avg       0.80      0.80      0.80        10
# weighted avg       0.80      0.80      0.80        10
#
# ROC-AUC: 0.92

# %%
from sklearn import dummy
from sklearn.dummy import DummyClassifier
from sklearn.metrics import accuracy_score, classification_report
#highly imbalanced data
y_true = [0]*95 +[1]*5 #95 non-fraud , 5 fraud
dummy = DummyClassifier(strategy="most_frequent")
dummy.fit([[0]]*100,y_true)
y_pred = dummy.predict([[0]]*100)
print(f"Accuracy: {accuracy_score(y_true, y_pred)}")
print(classification_report(y_true, y_pred))
# Out:
# Accuracy: 0.95
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        95
#            1       0.00      0.00      0.00         5
#
#     accuracy                           0.95       100
#    macro avg       0.47      0.50      0.49       100
# weighted avg       0.90      0.95      0.93       100
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# ...

# %%
from.ensemble import RandomForestClassifier
from sklearn.datasets import load_iris
X, y = load_iris(return_X_y=True)
param_grid = {"n_estimators": [10, 50, 100],'max_depth': [2, 4, 6]}
grid = GridSearchCV(RandomForestClassifier(), param_grid, cv=5)
grid.fit(X, y)
print("Best Params:", grid.best_params_)
print("Best Score:", grid.best_score_)
# Out:
# Best Params: {'max_depth': 4, 'n_estimators': 50}
# Best Score: 0.9666666666666668

# %%
# Out:
# Best Params: {'max_depth': 8, 'n_estimators': 142}
# Best Score: 0.9666666666666668

# %%
from sklearn.model_selection import cross_val_score
import numpy as np

score = cross_val_score(model, X, y, cv=5) # Changed 'x' to 'X' to ensure consistent sample sizes
print("cross-val scores:", score)
print("mean score:", np.mean(score))
# Out:
# cross-val scores: [0.         0.85124923 0.         0.76155439 0.        ]
# mean score: 0.3225607248900085
